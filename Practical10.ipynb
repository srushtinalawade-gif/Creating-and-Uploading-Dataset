# %% [markdown]
# <a href="https://colab.research.google.com/github/srushtinalawade-gif/Creating-and-Uploading-Dataset/blob/main/Practical10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating and Uploading Dataset using Pandas
# ## Name: Srushti J. Nalawade
# ## PRN: 25070123157
# ## Batch: ENTC A1
# ##Experiment 10

# %%
import pandas as pd

data={
    'Roll_No':[1,2,3,4,5],
    'Gender':['F','M','F','M','F'],
    'Department':['ENTC','RA','Mech','AIML','CSE'],
    'CGPA':[9.6,9.5,8.4,8.5,7.6]
}

df=pd.DataFrame(data)

df.to_csv('student_database.csv',index=False)
df
# Out:
#    Roll_No Gender Department  CGPA
# 0        1      F       ENTC   9.6
# 1        2      M         RA   9.5
# 2        3      F       Mech   8.4
# 3        4      M       AIML   8.5
# 4        5      F        CSE   7.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll_No     5 non-null      int64
#  1   Gender      5 non-null      object
#  2   Department  5 non-null      object
#  3   CGPA        5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
df.shape
# Out:
# (5, 4)

# %%
#Access information about a column
df['Department']
# Out:
# 0    ENTC
# 1      RA
# 2    Mech
# 3    AIML
# 4     CSE
# Name: Department, dtype: object

# %%
#Access information about a row
df.loc[2]
# Out:
# Roll_No          3
# Gender           F
# Department    Mech
# CGPA           8.4
# Name: 2, dtype: object

# %%
#Data type of each column
df.dtypes
# Out:
# Roll_No         int64
# Gender         object
# Department     object
# CGPA          float64
# dtype: object

# %%
#Perform mean, median, mode
mean=df['CGPA'].mean()
median=df['CGPA'].median()
mode=df['Department'].mode()

print(mean)
print(median)
print(mode)
# Out:
# 8.72
# 8.5
# 0    AIML
# 1     CSE
# 2    ENTC
# 3    Mech
# 4      RA
# Name: Department, dtype: object

# %%
#Insert a new column
df['Grade']=[96,94,81,85,71]
df
# Out:
#    Roll_No Gender Department  CGPA  Grade
# 0        1      F       ENTC   9.6     96
# 1        2      M         RA   9.5     94
# 2        3      F       Mech   8.4     81
# 3        4      M       AIML   8.5     85
# 4        5      F        CSE   7.6     71

# %%
#Delete a column
df.drop('Gender',axis=1,inplace=True)
df
# Out:
#    Roll_No Department  CGPA  Grade
# 0        1       ENTC   9.6     96
# 1        2         RA   9.5     94
# 2        3       Mech   8.4     81
# 3        4       AIML   8.5     85
# 4        5        CSE   7.6     71

# %%
#CGPA of Topper
df.loc[0,'CGPA']
# Out:
# np.float64(9.6)

# %%
df.iloc[4,2]
# Out:
# np.float64(7.6)

# %% [markdown]
# #Load Dataset

# %%
import numpy as np
df=pd.read_csv('/Cars93.csv')

# %%
df.size
# Out:
# 930

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Manufacturer    93 non-null     object
#  1   Model           93 non-null     object
#  2   Type            93 non-null     object
#  3   Price           93 non-null     float64
#  4   MPG.city        93 non-null     int64
#  5   AirBags         59 non-null     object
#  6   Horsepower      93 non-null     int64
#  7   Passengers      93 non-null     int64
#  8   Rear.seat.room  91 non-null     float64
#  9   Luggage.room    82 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 7.4+ KB

# %%
df.shape
# Out:
# (93, 10)

# %%
df.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25                 NaN
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
df.tail()
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 88   Volkswagen  Eurovan      Van   19.7        17                 NaN
# 89   Volkswagen   Passat  Compact   20.0        21                 NaN
# 90   Volkswagen  Corrado   Sporty   23.3        18                 NaN
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 88         109           7            34.0           NaN
# 89         134           5            31.5          14.0
# 90         178           4            26.0          15.0
# 91         114           5            29.5          14.0
# 92         168           5            30.0          15.0
